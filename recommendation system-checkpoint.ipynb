# %%
import requests
import base64

CLIENT_ID = '7555108234c542e2973b6847677d7a87'
CLIENT_SECRET = '28d46bd1fe174999a1e62a0ccc18259b'

# Encode the client credentials
credentials = f'{CLIENT_ID}:{CLIENT_SECRET}'
encoded_credentials = base64.b64encode(credentials.encode()).decode()

# Set up the headers and payload for the token request
headers = {'Authorization': f'Basic {encoded_credentials}'}
data = {'grant_type': 'client_credentials'}

# Make the token request
response = requests.post('https://accounts.spotify.com/api/token', headers=headers, data=data)

if response.status_code == 200:
    # Extract the access token from the response
    access_token = response.json()['access_token']
    print("New access token:", access_token)
else:
    print("Failed to obtain an access token. Status code:", response.status_code)
# Out:
# New access token: BQB_4RG8VtqXrqisqjR8az1J3Ye5jITdXNDDt4pIQ95IFWqEvgXW_Hlxljl-lwtZby4l7XTJAcMzYX0wco5NLPV2Y4UGQHLYWBIoMFnZnzBIp_knSD8

# %%
import pandas as pd
import spotipy
from spotipy.oauth2 import SpotifyOAuth

def get_trending_playlist_data(playlist_id, access_token):
    sp = spotipy.Spotify(auth=access_token)

    playlist_tracks = sp.playlist_tracks(playlist_id, fields='items(track(id, name, artists, album(id, name)))')

    music_data = []
    for track_info in playlist_tracks['items']:
        track = track_info['track']
        track_name = track['name']
        artists = ', '.join([artist['name'] for artist in track['artists']])
        album_name = track['album']['name']
        album_id = track['album']['id']
        track_id = track['id']

        audio_features = sp.audio_features(track_id)[0] if track_id != 'Not available' else None

        try:
            album_info = sp.album(album_id) if album_id != 'Not available' else None
            release_date = album_info['release_date'] if album_info else None
        except:
            release_date = None

        try:
            track_info = sp.track(track_id) if track_id != 'Not available' else None
            popularity = track_info['popularity'] if track_info else None
        except:
            popularity = None
            
        track_data = {
            'Track Name': track_name,
            'Artists': artists,
            'Album Name': album_name,
            'Album ID': album_id,
            'Track ID': track_id,
            'Popularity': popularity,
            'Release Date': release_date,
            'Duration (ms)': audio_features['duration_ms'] if audio_features else None,
            'Explicit': track_info.get('explicit', None),
            'External URLs': track_info.get('external_urls', {}).get('spotify', None),
            'Danceability': audio_features['danceability'] if audio_features else None,
            'Energy': audio_features['energy'] if audio_features else None,
            'Key': audio_features['key'] if audio_features else None,
            'Loudness': audio_features['loudness'] if audio_features else None,
            'Mode': audio_features['mode'] if audio_features else None,
            'Speechiness': audio_features['speechiness'] if audio_features else None,
            'Acousticness': audio_features['acousticness'] if audio_features else None,
            'Instrumentalness': audio_features['instrumentalness'] if audio_features else None,
            'Liveness': audio_features['liveness'] if audio_features else None,
            'Valence': audio_features['valence'] if audio_features else None,
            'Tempo': audio_features['tempo'] if audio_features else None,
        }

        music_data.append(track_data)

    df = pd.DataFrame(music_data)

    return df

# %%
playlist_id = '0pEH5ZwPv6SqXwesUMslBE'

music_df = get_trending_playlist_data(playlist_id, access_token)

print(music_df)
# Out:
#                                           Track Name  \
# 0     Arabic Kuthu - Halamithi Habibo (From "Beast")
# 1                         Jalabulajangu (From "Don")
# 2                                        Mayakirriye
# 3                            Adiye - From "Bachelor"
# 4   Naan Pizhai (From "Kaathuvaakula Rendu Kaadhal")
# ..                                               ...
# 95                                  Kadal Raasa Naan
# 96                                  Yeppadi Irruntha
# 97                                      Naana Thaana
# 98                                   En Frienda Pola
# 99                                       Valayapatti
#
#                                           Artists  \
# 0              Anirudh Ravichander, Jonita Gandhi
# 1                     Anirudh Ravichander, Rokesh
# 2                     Anivee, Anirudh Ravichander
# 3               Dhibu Ninan Thomas, Kapil Kapilan
# 4   Anirudh Ravichander, Ravi G, Shashaa Tirupati
# ...

# %%
print(music_df.isnull().sum())
# Out:
# Track Name          0
# Artists             0
# Album Name          0
# Album ID            0
# Track ID            0
# Popularity          0
# Release Date        0
# Duration (ms)       0
# Explicit            0
# External URLs       0
# Danceability        0
# Energy              0
# Key                 0
# Loudness            0
# Mode                0
# Speechiness         0
# Acousticness        0
# Instrumentalness    0
# Liveness            0
# Valence             0
# Tempo               0
# dtype: int64

# %%
import pandas as pd
import numpy as np
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import MinMaxScaler
from datetime import datetime
from sklearn.metrics.pairwise import cosine_similarity

data = music_df
print(data)
# Out:
#                                           Track Name  \
# 0     Arabic Kuthu - Halamithi Habibo (From "Beast")
# 1                         Jalabulajangu (From "Don")
# 2                                        Mayakirriye
# 3                            Adiye - From "Bachelor"
# 4   Naan Pizhai (From "Kaathuvaakula Rendu Kaadhal")
# ..                                               ...
# 95                                  Kadal Raasa Naan
# 96                                  Yeppadi Irruntha
# 97                                      Naana Thaana
# 98                                   En Frienda Pola
# 99                                       Valayapatti
#
#                                           Artists  \
# 0              Anirudh Ravichander, Jonita Gandhi
# 1                     Anirudh Ravichander, Rokesh
# 2                     Anivee, Anirudh Ravichander
# 3               Dhibu Ninan Thomas, Kapil Kapilan
# 4   Anirudh Ravichander, Ravi G, Shashaa Tirupati
# ...

# %%
def calculate_weighted_popularity(release_date):
    release_date = datetime.strptime(release_date, '%Y-%m-%d')

    time_span = datetime.now() - release_date

    weight = 1 / (time_span.days + 1)
    return weight

# %%
scaler = MinMaxScaler()
music_features = music_df[['Danceability', 'Energy', 'Key', 
                           'Loudness', 'Mode', 'Speechiness', 'Acousticness',
                           'Instrumentalness', 'Liveness', 'Valence', 'Tempo']].values
music_features_scaled = scaler.fit_transform(music_features)

# %%
def content_based_recommendations(input_song_name, num_recommendations=5):
    if input_song_name not in music_df['Track Name'].values:
        print(f"'{input_song_name}' not found in the dataset. Please enter a valid song name.")
        return

    input_song_index = music_df[music_df['Track Name'] == input_song_name].index[0]

    similarity_scores = cosine_similarity([music_features_scaled[input_song_index]], music_features_scaled)

    similar_song_indices = similarity_scores.argsort()[0][::-1][1:num_recommendations + 1]

    content_based_recommendations = music_df.iloc[similar_song_indices][['Track Name', 'Artists', 'Album Name', 'Release Date', 'Popularity']]

    return content_based_recommendations

# %%
def hybrid_recommendations(input_song_name, num_recommendations=5, alpha=0.5):
    if input_song_name not in music_df['Track Name'].values:
        print(f"'{input_song_name}' not found in the dataset. Please enter a valid song name.")
        return

    content_based_rec = content_based_recommendations(input_song_name, num_recommendations)

    if content_based_rec is not None and not content_based_rec.empty:
        popularity_score = music_df.loc[music_df['Track Name'] == input_song_name, 'Popularity'].values[0]
        weighted_popularity_score = popularity_score * calculate_weighted_popularity(music_df.loc[music_df['Track Name'] == input_song_name, 'Release Date'].values[0])

        new_row_df = pd.DataFrame([{
            'Track Name': input_song_name,
            'Artists': music_df.loc[music_df['Track Name'] == input_song_name, 'Artists'].values[0],
            'Album Name': music_df.loc[music_df['Track Name'] == input_song_name, 'Album Name'].values[0],
            'Release Date': music_df.loc[music_df['Track Name'] == input_song_name, 'Release Date'].values[0],
            'Popularity': weighted_popularity_score
        }])

        hybrid_recommendations_df = pd.concat([content_based_rec, new_row_df], ignore_index=True)

        hybrid_recommendations_df = hybrid_recommendations_df.sort_values(by='Popularity', ascending=False)

        final_recommendations = hybrid_recommendations_df[hybrid_recommendations_df['Track Name'] != input_song_name].head(num_recommendations)
        
        return final_recommendations
    else:
        print("Content-based recommendations returned empty. Check your content-based function.")
        return

# %%
input_song_name = "Kadal Raasa Naan"
recommendations = hybrid_recommendations(input_song_name, num_recommendations=5)
print(f"Hybrid recommended songs for '{input_song_name}':")
print(recommendations)
# Out:
# Hybrid recommended songs for 'Kadal Raasa Naan':
#                                     Track Name  \
# 2                               Chammak Challo
# 4  Kannala Kannala - The Melting Point of Love
# 0                            Suthudhe Suthudhe
# 1                                  Kodu Poatta
# 3                                       Oxygen
#
#                                         Artists  \
# 2                            Akon, Hamsika Iyer
# 4     Hiphop Tamizha, Kaushik Krish, Padmalatha
# 0  Yuvan Shankar Raja, Karthik, Sunitha Sarathy
# 1                      A.R. Rahman, Benny Dayal
# 3                Hiphop Tamizha,Sudarshan Ashok
#
#                                           Album Name Release Date  Popularity
# 2                                             Ra-One   2011-09-16        74.0
# 4  Thani Oruvan (Original Motion Picture Soundtrack)   2015-07-22        65.0
# 0         Paiya (Original Motion Picture Soundtrack)   2010-11-22        53.0
# ...

# %%
input_song_name = 'Arabic Kuthu - Halamithi Habibo (From "Beast")'
recommendations = hybrid_recommendations(input_song_name, num_recommendations=5)
print(f"Hybrid recommended songs for '{input_song_name}':")
print(recommendations)
# Out:
# Hybrid recommended songs for 'Arabic Kuthu - Halamithi Habibo (From "Beast")':
#                                          Track Name  \
# 4                            Orasaadha - Madras Gig
# 2  Two Two Two (From "Kaathuvaakula Rendu Kaadhal")
# 3                                 Ulagam Oruvanukka
# 0                                       Kalaarasiga
# 1                                    Nenjukulla Nee
#
#                                              Artists  \
# 4                                     Vivek - Mervin
# 2  Anirudh Ravichander, Sunidhi Chauhan, Sanjana ...
# 3  Santhosh Narayanan, Ananthu, Gana Bala, Roshan...
# 0                          A.R. Rahman, Shweta Mohan
# 1                        Vijay Prakash,Diwakar,Ajesh
#
#                                          Album Name Release Date  Popularity
# 4                            Orasaadha (Madras Gig)   2018-06-12        64.0
# 2  Two Two Two (From "Kaathuvaakula Rendu Kaadhal")   2021-09-18        59.0
# ...

# %%
input_song_name = 'Nee Paartha Vizhigal - The Touch of Love'
recommendations = hybrid_recommendations(input_song_name, num_recommendations=5)
print(f"Hybrid recommended songs for '{input_song_name}':")
print(recommendations)
# Out:
# Hybrid recommended songs for 'Nee Paartha Vizhigal - The Touch of Love':
#                               Track Name  \
# 3                          Kanave Kanave
# 2  Don'u Don'u Don'u - The Don's Romance
# 0             Thuli Thuli (From "Paiya")
# 1                                 Yaanji
# 4                              Munbe Vaa
#
#                                              Artists  \
# 3                                Anirudh Ravichander
# 2                 Anirudh Ravichander, Alisha Thomas
# 0         Yuvan Shankar Raja, Haricharan, Tanvi Shah
# 1  Anirudh Ravichander, Sam C.S., Shakthisree Gop...
# 4           A.R. Rahman, Naresh Iyer, Shreya Ghoshal
#
#                                           Album Name Release Date  Popularity
# 3                                              David   2013-01-10        68.0
# 2         Maari (Original Motion Picture Soundtrack)   2015-06-07        60.0
# 0                  All About Love: Yuvanshankar Raja   2018-08-31        59.0
# ...
